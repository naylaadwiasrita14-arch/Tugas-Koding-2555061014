# %%
import torch

# %%
# selesaikan soal berikut
# what is the transpose pf this vector below

x = torch.tensor([[25], [2], [-3]])
x
# Out:
# tensor([[25],
#         [ 2],
#         [-3]])

# %%
# Transpose
x.T
# Out:
# tensor([[25,  2, -3]])
