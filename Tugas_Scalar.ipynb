# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x = 14
x
# Out:
# 14

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y = 41
y
# Out:
# 41

# %%
# jumlahkan x+y
py_sum = x + y
py_sum
# Out:
# 55

# %%
# buat variabel bernama x_float dan simpan suatu nilai desima
x_float = 14.0
float_sum = x_float + y
float_sum
# Out:
# 55.0
